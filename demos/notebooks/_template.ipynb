# %% [markdown]
# # Demonstration title
#
# ## What this demonstrates
#
# State one bounded capability.
#
# ## Why it matters
#
# Explain the problem it solves.
#
# ## Source and package mapping
#
# Link production examples and packages.
#
# ## Application
#
# Show where it belongs in a system.
#
# ## Boundaries and limitations
#
# State what it does not prove.
#
# ## Reproduction record
#
# Describe generated evidence.

# %%
raise NotImplementedError("Replace the template cell")
